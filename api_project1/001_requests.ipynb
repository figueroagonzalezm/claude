# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.100.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Using cached jiter-0.14.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from anthropic)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.14 (from anthropic)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached pydantic_core-2.46.4-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.100.0-py3-none-any.whl (753 kB)
#    ---------------------------------------- 0.0/753.6 kB ? eta -:--:--
#    ---------------------------------------- 753.6/753.6 kB 7.8 MB/s eta 0:00:00
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached jiter-0.14.0-cp312-cp312-win_amd64.whl (201 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, sniffio, python-dotenv, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, anthropic
# Successfully installed annotated-types-0.7.0 anthropic-0.100.0 anyio-4.13.0 certifi-2026.4.22 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 jiter-0.14.0 pydantic-2.13.4 pydantic-core-2.46.4 python-dotenv-1.2.2 sniffio-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Get user input
# Add user input to the list of messages
# Call claude
# Print the generated response
# Add generated response to the list of messages
# Repeat

while True:
    user_input = input(">")
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("---")
    print(answer)
    print("---")
# Out:
# C:\Users\Miguel_Figueroa2\AppData\Local\Temp\ipykernel_8776\2201200310.py:10: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(
# ---
# React is a popular JavaScript library for building user interfaces, particularly web applications. Here are the key things to know about React:
#
# ## What React Is
# - **JavaScript Library**: Created by Facebook (now Meta) in 2013
# - **Component-Based**: Build UIs using reusable, modular components
# - **Declarative**: Describe what the UI should look like rather than how to manipulate it
#
# ## Core Features
#
# ### 1. **Components**
# ```jsx
# function Welcome(props) {
#   return <h1>Hello, {props.name}!</h1>;
# }
# ```
#
# ### 2. **JSX (JavaScript XML)**
# - Syntax extension that lets you write HTML-like code in JavaScript
# ```jsx
# const element = <h1>Hello, World!</h1>;
# ```
#
# ### 3. **Virtual DOM**
# - React creates a virtual representation of the DOM
# - Efficiently updates only the parts that changed
#
# ### 4. **State Management**
# ```jsx
# const [count, setCount] = useState(0);
# ```
#
# ## Key Benefits
# - **Reusability**: Write once, use anywhere
# - **Performance**: Virtual DOM optimization
# - **Large Ecosystem**: Extensive community and libraries
# - **Developer Tools**: Great debugging and development experience
# - **Flexibility**: Can be integrated into existing projects
#
# ## Common Use Cases
# - Single Page Applications (SPAs)
# - Web applications
# - Mobile apps (with React Native)
# - Desktop applications (with Electron)
#
# React has become one of the most widely used frontend frameworks alongside Vue.js and Angular, known for its simplicity and powerful features for building modern web applications.
# ---
# ---
# React is a JavaScript library for building user interfaces using reusable components and a virtual DOM for efficient rendering.
# ---
# ---
# React is a JavaScript library for building user interfaces with reusable components.
# ---
